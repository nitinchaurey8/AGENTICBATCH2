# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.getenv("LANGCHAIN_PROJECT")
# Out:
# 'Agentic2.0'

# %%
os.getenv("LANGCHAIN_API_KEY")
# Out:
# 'lsv2_pt_REDACTED'

# %%
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

## Langsmith Tracking And Tracing
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")
os.environ["LANGCHAIN_TRACING_V2"]="true"

# %%
from langchain_openai import ChatOpenAI

llm=ChatOpenAI(model="gpt-4o-mini")
print(llm)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x00000237C97C16D0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000237C97C11D0> root_client=<openai.OpenAI object at 0x00000237C97C1090> root_async_client=<openai.AsyncOpenAI object at 0x00000237C97C1950> model_name='gpt-4o-mini' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
result=llm.invoke("What is Agentic AI")
print(result)
# Out:
# content='Agentic AI refers to a type of artificial intelligence that possesses a degree of autonomy and decision-making capability, allowing it to perform tasks and make choices independently based on the parameters set by its programming and the data it processes. Unlike traditional AI systems that primarily act as tools for human operators or follow predefined rules, agentic AI can adapt to new situations, learn from experiences, and potentially act on behalf of users.\n\nKey characteristics of agentic AI include:\n\n1. **Autonomy**: The ability to operate independently and make decisions without direct human intervention.\n2. **Learning Capability**: The ability to learn from data and experiences, improving its performance over time.\n3. **Goal-Oriented Behavior**: It can pursue specific objectives or goals, making plans and taking actions to achieve them.\n4. **Interaction with the Environment**: Agentic AI can sense and interpret information from its environment to inform its decisions.\n\nAgentic AI can be used in various applications, including autonomous vehicles, personal assistants, chatbot systems, and robotics, where it can enhance efficiency, perform complex tasks, and improve user experiences. However, the development and deployment of such systems also raise important ethical and safety considerations, particularly concerning accountability, transparency, and potential biases in decision-making processes.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 252, 'prompt_tokens': 12, 'total_tokens': 264, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_373a14eb6f', 'id': 'chatcmpl-DDNvIvHRhLPbfhYprrQFiEIIacTIS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c985a-8395-7d00-b3e8-398145f4ea79-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 252, 'total_tokens': 264, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
print(result.content)
# Out:
# Agentic AI refers to a type of artificial intelligence that possesses a degree of autonomy and decision-making capability, allowing it to perform tasks and make choices independently based on the parameters set by its programming and the data it processes. Unlike traditional AI systems that primarily act as tools for human operators or follow predefined rules, agentic AI can adapt to new situations, learn from experiences, and potentially act on behalf of users.
#
# Key characteristics of agentic AI include:
#
# 1. **Autonomy**: The ability to operate independently and make decisions without direct human intervention.
# 2. **Learning Capability**: The ability to learn from data and experiences, improving its performance over time.
# 3. **Goal-Oriented Behavior**: It can pursue specific objectives or goals, making plans and taking actions to achieve them.
# 4. **Interaction with the Environment**: Agentic AI can sense and interpret information from its environment to inform its decisions.
#
# Agentic AI can be used in various applications, including autonomous vehicles, personal assistants, chatbot systems, and robotics, where it can enhance efficiency, perform complex tasks, and improve user experiences. However, the development and deployment of such systems also raise important ethical and safety considerations, particularly concerning accountability, transparency, and potential biases in decision-making processes.

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.3-70b-versatile")
model.invoke("Hi My name is Krish")
# Out:
# AIMessage(content="Hello Krish, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 40, 'total_tokens': 66, 'completion_time': 0.04311022, 'completion_tokens_details': None, 'prompt_time': 0.001730581, 'prompt_tokens_details': None, 'queue_time': 0.160876219, 'total_time': 0.044840801}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019c985b-e224-77b3-9484-4ce352873af9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 26, 'total_tokens': 66})

# %%
### Prompt Engineering
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answer based on the question"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answer based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="gemma2-9b-it")
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x0000019DE3B4DD10>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000019DE3B4E850>, model_name='gemma2-9b-it', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
### chaining
chain=prompt|model
chain
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answer based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])
# | ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x00000237C9AC6710>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000237C9AC7250>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
response=chain.invoke({"input":"Can you tell me something about Langsmith"})
print(response.content)
# Out:
# Langsmith is an AI-powered platform that allows users to create, train, and deploy custom language models. It provides a suite of tools and services for building, fine-tuning, and integrating language models into various applications.
#
# Here are some key features and capabilities of Langsmith:
#
# 1. **Custom Language Model Creation**: Langsmith enables users to create custom language models tailored to their specific use cases, such as chatbots, virtual assistants, or content generation.
# 2. **Model Training and Fine-Tuning**: The platform provides a range of pre-trained models and allows users to fine-tune them using their own datasets, which can improve the model's performance and adapt it to specific domains or industries.
# 3. **Integration with Various Applications**: Langsmith offers APIs and SDKs for integrating custom language models with various applications, such as messaging platforms, voice assistants, or web applications.
# 4. **Support for Multiple Languages**: Langsmith supports multiple languages, including English, Spanish, French, German, Chinese, and many others, making it a versatile platform for global applications.
# 5. **Collaboration and Version Control**: The platform provides features for collaboration and version control, allowing multiple users to work together on language model development and track changes.
# 6. **Model Evaluation and Testing**: Langsmith offers tools for evaluating and testing language models, including metrics such as perplexity, accuracy, and F1 score, to help users assess their model's performance.
#
# Langsmith is designed to cater to a wide range of users, from developers and data scientists to business professionals and entrepreneurs, who want to leverage the power of language models to build innovative applications and solutions.
#
# Would you like to know more about Langsmith or is there something specific you'd like to ask?

# %%
### OutputParser
from langchain_core.output_parsers import StrOutputParser

output_parser=StrOutputParser()

chain=prompt|model|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith"})
print(response)
# Out:
# Langsmith is an AI model developed by Meta AI, designed to process and generate human-like language. It's a type of large language model (LLM) that uses natural language processing (NLP) and machine learning algorithms to understand and respond to human input.
#
# Here are some key features and capabilities of Langsmith:
#
# 1. **Language Understanding**: Langsmith is trained on a massive dataset of text from various sources, allowing it to learn patterns and relationships in language. This enables it to understand the context and meaning of human input.
# 2. **Text Generation**: Langsmith can generate human-like text based on a given prompt or topic. It can create coherent and contextually relevant text, including articles, stories, and conversations.
# 3. **Conversational Dialogue**: Langsmith can engage in natural-sounding conversations, using context and understanding to respond to questions and statements.
# 4. **Language Translation**: Langsmith can translate text from one language to another, including popular languages such as Spanish, French, German, Chinese, and many more.
# 5. **Summarization and Paraphrasing**: Langsmith can summarize long pieces of text into shorter, more concise versions, and paraphrase text to convey the same meaning in different words.
# 6. **Content Creation**: Langsmith can be used to generate content, such as blog posts, social media posts, and even entire books.
#
# Langsmith's capabilities are based on its training data, which includes a massive corpus of text from various sources, including books, articles, and online conversations. This training data allows Langsmith to learn patterns and relationships in language, enabling it to generate human-like text and engage in natural-sounding conversations.
#
# Some potential applications of Langsmith include:
#
# 1. **Virtual Assistants**: Langsmith can be used to power virtual assistants, such as chatbots and voice assistants, to provide more natural and human-like interactions.
# 2. **Content Creation**: Langsmith can be used to generate high-quality content, such as blog posts, articles, and social media posts, saving time and effort for content creators.
# 3. **Language Learning**: Langsmith can be used to help language learners practice their language skills, such as conversation and writing.
# 4. **Customer Service**: Langsmith can be used to power customer service chatbots, providing more natural and human-like interactions with customers.
#
# Overall, Langsmith is a powerful AI model that has the potential to revolutionize the way we interact with language and generate content.

# %%
from langchain_core.output_parsers import JsonOutputParser

output_parser=JsonOutputParser()
output_parser.get_format_instructions()
# Out:
# 'Return a JSON object.'

# %%
### OutputParser
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate

output_parser=JsonOutputParser()

prompt=PromptTemplate(
    template="Answer the user query \n {format_instruction}\n {query}\n ",
    input_variables=["query"],
    partial_variables={"format_instruction":output_parser.get_format_instructions()},
)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['query'], input_types={}, partial_variables={'format_instruction': 'Return a JSON object.'}, template='Answer the user query \n {format_instruction}\n {query}\n ')

# %%
chain=prompt|model|output_parser
response=chain.invoke({"query":"Can you tell me about Langsmith?"})
print(response)
# Out:
# {'name': 'Langsmith', 'description': 'A language learning platform', 'features': ['Personalized learning plans', 'Interactive lessons', 'Speech recognition technology'], 'goal': 'To help users learn new languages effectively and efficiently'}

# %%
### Assisgnment ---Chatprompttemplate

### Prompt Engineering
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer.Provide the response in json.Provide me answer based on the question"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer.Provide the response in json.Provide me answer based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt|model|output_parser
response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# {'response': {'description': 'Langsmith is an AI-powered language learning platform that utilizes natural language processing (NLP) and machine learning algorithms to provide personalized language lessons and exercises.', 'features': ['Interactive lessons and exercises', 'Personalized learning paths', 'Speech recognition technology', 'Grammar and vocabulary correction', 'Conversation practice with AI chatbots'], 'benefits': ['Improved language proficiency', 'Enhanced speaking and writing skills', 'Increased confidence in language use', 'Access to a wide range of languages and courses'], 'target_audience': ['Language learners', 'Students', 'Travelers', 'Business professionals']}}

# %% [markdown]
# ### Assigments: https://python.langchain.com/docs/how_to/#prompt-templates

# %%
### OutputParser
from langchain_core.output_parsers import XMLOutputParser
output_parser=XMLOutputParser()
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer.<response><answer>Your answer here</answer></response>.Provide me answer based on the question"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer.<response><answer>Your answer here</answer></response>.Provide me answer based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
### OutputParser
from langchain_core.output_parsers import XMLOutputParser
from langchain_core.prompts import PromptTemplate

output_parser=XMLOutputParser()

prompt=PromptTemplate(
    template="Answer the user query \n {format_instruction}\n {query}\n ",
    input_variables=["query"],
    partial_variables={"format_instruction":output_parser.get_format_instructions()},
)
prompt
# Out:
# PromptTemplate(input_variables=['query'], input_types={}, partial_variables={'format_instruction': 'The output should be formatted as a XML file.\n1. Output should conform to the tags below.\n2. If tags are not given, make them on your own.\n3. Remember to always open and close all the tags.\n\nAs an example, for the tags ["foo", "bar", "baz"]:\n1. String "<foo>\n   <bar>\n      <baz></baz>\n   </bar>\n</foo>" is a well-formatted instance of the schema.\n2. String "<foo>\n   <bar>\n   </foo>" is a badly-formatted instance.\n3. String "<foo>\n   <tag>\n   </tag>\n</foo>" is a badly-formatted instance.\n\nHere are the output tags:\n```\nNone\n```'}, template='Answer the user query \n {format_instruction}\n {query}\n ')

# %%
chain=prompt|model
response=chain.invoke({"query":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='<response>\n  <information>\n    <about>Langsmith</about>\n    <description>Langsmith is an AI designed to generate human-like text based on the input it receives. It can be used for a variety of tasks such as answering questions, creating content, and even just chatting with users.</description>\n  </information>\n  <capabilities>\n    <generation>Text Generation</generation>\n    <conversation>Conversation Handling</conversation>\n  </capabilities>\n</response>' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 98, 'prompt_tokens': 201, 'total_tokens': 299, 'completion_time': 0.383519395, 'completion_tokens_details': None, 'prompt_time': 0.025876711, 'prompt_tokens_details': None, 'queue_time': 0.049210764, 'total_time': 0.409396106}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_68f543a7cc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019c989b-d4b5-7040-b9ba-d38b92d94eb5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 201, 'output_tokens': 98, 'total_tokens': 299}

# %%
##output parser
from langchain_core.output_parsers import XMLOutputParser

# XML Output Parser
output_parser = XMLOutputParser()

# Prompt that instructs the model to return XML
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant. Respond in this XML format: <response><answer>Your answer here</answer></response>"),
    ("human", "{input}")
])

# Build the chain
chain = prompt | model

# Run the chain
raw_output = chain.invoke({"input": "What is LangChain?"})

# Print result
print(raw_output)
# Out:
# content='<response><answer>LangChain is an open-source framework designed to help developers build applications that utilize large language models (LLMs) like ChatGPT, LLaMA, and others. It provides a set of tools and libraries that simplify the process of integrating LLMs into various projects, such as chatbots, virtual assistants, and other AI-powered applications. LangChain aims to make it easier for developers to focus on building their applications rather than spending time on the underlying infrastructure and plumbing required to work with LLMs. The framework offers features like model serving, caching, and queueing, as well as support for multiple LLMs and deployment options, making it a popular choice among developers and researchers working with large language models.</answer></response>' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 154, 'prompt_tokens': 64, 'total_tokens': 218, 'completion_time': 0.508972528, 'completion_tokens_details': None, 'prompt_time': 0.002239236, 'prompt_tokens_details': None, 'queue_time': 0.048214624, 'total_time': 0.511211764}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c06d5113ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019c989d-63b0-75e3-b86a-787a89e370cd-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 64, 'output_tokens': 154, 'total_tokens': 218}

# %%
## With Pydantic
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field

model = ChatOpenAI(temperature=0.7)


# Define your desired data structure.
class Joke(BaseModel):
    setup: str = Field(description="question to set up a joke")
    punchline: str = Field(description="answer to resolve the joke")


# And a query intented to prompt a language model to populate the data structure.
joke_query = "Tell me a joke."

# Set up a parser + inject instructions into the prompt template.
parser = JsonOutputParser(pydantic_object=Joke)

prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | model | parser

chain.invoke({"query": joke_query})
# Out:
# {'setup': "Why don't scientists trust atoms?",
#  'punchline': 'Because they make up everything!'}

# %%
### Without Pydantic
joke_query = "Tell me a joke ."

parser = JsonOutputParser()

prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | model | parser

chain.invoke({"query": joke_query})
# Out:
# {'joke': "Why couldn't the bicycle stand up by itself? Because it was two tired!"}

# %%
from langchain_core.output_parsers import XMLOutputParser
from langchain_core.prompts import PromptTemplate


actor_query = "Generate the shortened filmography for Tom Hanks."

output = model.invoke(
    f"""{actor_query}
Please enclose the movies in <movie></movie> tags"""
)

print(output.content)
# Out:
# <movie>Splash</movie>
# <movie>Big</movie>
# <movie>A League of Their Own</movie>
# <movie>Forrest Gump</movie>
# <movie>Toy Story</movie>
# <movie>Cast Away</movie>
# <movie>The Da Vinci Code</movie>
# <movie>Sully</movie>
# <movie>Bridge of Spies</movie>
# <movie>News of the World</movie>

# %%
from langchain.output_parsers import YamlOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field


# Define your desired data structure.
class Joke(BaseModel):
    setup: str = Field(description="question to set up a joke")
    punchline: str = Field(description="answer to resolve the joke")


model = ChatOpenAI(temperature=0.5)

# And a query intented to prompt a language model to populate the data structure.
joke_query = "Tell me a joke."

# Set up a parser + inject instructions into the prompt template.
parser = YamlOutputParser(pydantic_object=Joke)

prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | model | parser

chain.invoke({"query": joke_query})
# Out:
# Joke(setup="Why don't scientists trust atoms?", punchline='Because they make up everything!')

# %% [markdown]
# ### Assisgment:
# Create a simple assistant that uses any LLM and should be pydantic, when we ask about any product it should give you two information product Name, product details tentative price in USD (integer). use chat Prompt Template.

# %%
from pydantic import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser

class ProductInfo(BaseModel):
    product_name: str = Field(description="Product name")
    product_details: str = Field(description="Short product details")
    tentative_price_usd: int = Field(description="Tentative price in USD as an integer")

output_parser = PydanticOutputParser(pydantic_object=ProductInfo)

product_prompt = ChatPromptTemplate.from_messages([
    (
        "system",
        "You are a product assistant. "
        "Answer product questions with realistic information and provide a tentative USD price as an integer. "
        "Return only valid JSON in the required schema.\n{format_instructions}",
    ),
    ("human", "Question: {question}"),
])

product_chain = product_prompt | llm | output_parser

question = "Tell me about Apple AirPods Pro 2"
product_answer = product_chain.invoke(
    {
        "question": question,
        "format_instructions": output_parser.get_format_instructions(),
    }
)

print(product_answer.model_dump())
# Out:
# {'product_name': 'Apple AirPods Pro 2', 'product_details': 'The Apple AirPods Pro 2 feature active noise cancellation, transparency mode, and an improved battery life. They come with a custom spatial audio experience, enhanced sound quality, and a new H2 chip for better performance.', 'tentative_price_usd': 249}
